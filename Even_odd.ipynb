# %% [markdown]
# <a href="https://colab.research.google.com/github/adilmomin288-hub/aiml-project/blob/main/Even_odd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even Number")
else:
    print("Odd Number")
# Out:
# Enter a number: 34
# Even Number
