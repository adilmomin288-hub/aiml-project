# %% [markdown]
# <a href="https://colab.research.google.com/github/adilmomin288-hub/aiml-project/blob/main/Swap_to_variable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10
b = 20

a = a + b
b = a - b
a = a - b

print("a =", a)
print("b =", b)
# Out:
# a = 20
# b = 10
