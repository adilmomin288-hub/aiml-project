# %% [markdown]
# <a href="https://colab.research.google.com/github/adilmomin288-hub/aiml-project/blob/main/Reverse_string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = input("Enter a string: ")

reverse = ""

for char in text:
    reverse = char + reverse

print("Reversed String:", reverse)
# Out:
# Enter a string: 234
# Reversed String: 432
